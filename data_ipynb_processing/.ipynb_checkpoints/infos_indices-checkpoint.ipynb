# %%
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
import numpy as np
import yfinance as yf
import html5lib

# %%
indices = {
    "Nom_Indice": ['CAC40', 'DAX40', 'FTSE MIB40', 'IBEX35', 'BEL20', 'AEX25', 'FTSE100', 'SP500', 'NASDAQ100', 'DowJones30', 'OMX Helsinki 25', 'OMX Stockholm 30', 'OMX Copenhagen 25', 'STOXX50', 'NIKKEI225'],
    "Ticker": ['PX1', 'DAX', 'FTSEMIB', 'INDI', 'BEL20', 'AEX', 'UKX', 'GSPC', 'NDX', 'DJI', 'OMCH25', 'OMXS30', 'OMXC25', 'SX5E', 'NI225'],
    "Ticker_Yahoo_Finance": ['^FCHI', '^GDAXI', 'FTSEMIB.MI', '^IBEX', '^BFX', '^AEX', '^FTSE', '^GSPC', '^NDX', '^DJI', '^OMXH25', '^OMX', '^OMXC25', '^STOXX50E', '^N225'],
    "Pays": ['France', 'Germany', 'Italy', 'Spain', 'Belgium', 'Netherlands', 'United Kingdom', 'United States', 'United States', 'United States', 'Finland', 'Sweden', 'Danemark', 'Europe', 'Japan'],
    "Nombres_Entreprises": [40, 40, 40, 35, 20, 25, 100, 500, 100, 30, 25, 30, 25, 50, 225],
    }

# Création du DataFrame
df = pd.DataFrame(indices)

# Listes pour stocker les nouvelles informations
currencies = []
place_boursiere = []
short_name = []

# Récupération des informations via yfinance
for i in df["Ticker_Yahoo_Finance"]:
    try:
        info = yf.Ticker(i).info  # Récupération des infos générales
        
        # Extraction des données
        currency = info.get("currency", "Non disponible")
        exchange = info.get("exchange", "Non disponible")
        short_name_entreprise = info.get('shortName', 'Non disponible')
        
    except Exception as e:
        currency = "Non disponible"
        exchange = "Non disponible"
        short_name_entreprise = "Non disponible"
        
    # Ajout des valeurs aux listes
    currencies.append(currency)
    place_boursiere.append(exchange)
    short_name.append(short_name_entreprise)

# Ajout des nouvelles colonnes au DataFrame
df["Devise"] = currencies
df["Place_Boursiere"] = place_boursiere
df["Short_Name"] = short_name

# Réorganisation des colonnes
df = df[
    ["Nom_Indice", 'Ticker', 'Ticker_Yahoo_Finance', "Short_Name", 'Pays', 'Place_Boursiere', 'Nombres_Entreprises', "Devise"]
    ]

# Enregistrement du fichier .csv
df.to_csv("/Users/bastoch/ProjectFinance_alleger/data_csv/historique_indices/infos_indices.csv", index=False, encoding='utf-8')

display(df)
# Out:
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/%5EFCHI?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=%5EFCHI&crumb=Edge%3A+Too+Many+Requests
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/%5EGDAXI?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=%5EGDAXI&crumb=Edge%3A+Too+Many+Requests
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/FTSEMIB.MI?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=FTSEMIB.MI&crumb=Edge%3A+Too+Many+Requests
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/%5EIBEX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=%5EIBEX&crumb=Edge%3A+Too+Many+Requests
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/%5EBFX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=%5EBFX&crumb=Edge%3A+Too+Many+Requests
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/%5EAEX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=%5EAEX&crumb=Edge%3A+Too+Many+Requests
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/%5EFTSE?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=%5EFTSE&crumb=Edge%3A+Too+Many+Requests
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/%5EGSPC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=%5EGSPC&crumb=Edge%3A+Too+Many+Requests
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/%5ENDX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=%5ENDX&crumb=Edge%3A+Too+Many+Requests
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/%5EDJI?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=%5EDJI&crumb=Edge%3A+Too+Many+Requests
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/%5EOMXH25?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=%5EOMXH25&crumb=Edge%3A+Too+Many+Requests
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/%5EOMX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=%5EOMX&crumb=Edge%3A+Too+Many+Requests
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/%5EOMXC25?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=%5EOMXC25&crumb=Edge%3A+Too+Many+Requests
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/%5ESTOXX50E?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=%5ESTOXX50E&crumb=Edge%3A+Too+Many+Requests
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/%5EN225?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=%5EN225&crumb=Edge%3A+Too+Many+Requests
#            Nom_Indice   Ticker Ticker_Yahoo_Finance      Short_Name  \
# 0               CAC40      PX1                ^FCHI  Non disponible
# 1               DAX40      DAX               ^GDAXI  Non disponible
# 2          FTSE MIB40  FTSEMIB           FTSEMIB.MI  Non disponible
# 3              IBEX35     INDI                ^IBEX  Non disponible
# 4               BEL20    BEL20                 ^BFX  Non disponible
# 5               AEX25      AEX                 ^AEX  Non disponible
# 6             FTSE100      UKX                ^FTSE  Non disponible
# 7               SP500     GSPC                ^GSPC  Non disponible
# 8           NASDAQ100      NDX                 ^NDX  Non disponible
# 9          DowJones30      DJI                 ^DJI  Non disponible
# 10    OMX Helsinki 25   OMCH25              ^OMXH25  Non disponible
# 11   OMX Stockholm 30   OMXS30                 ^OMX  Non disponible
# 12  OMX Copenhagen 25   OMXC25              ^OMXC25  Non disponible
# 13            STOXX50     SX5E            ^STOXX50E  Non disponible
# 14          NIKKEI225    NI225                ^N225  Non disponible
#
#               Pays Place_Boursiere  Nombres_Entreprises          Devise
# 0           France  Non disponible                   40  Non disponible
# 1          Germany  Non disponible                   40  Non disponible
# 2            Italy  Non disponible                   40  Non disponible
# 3            Spain  Non disponible                   35  Non disponible
# 4          Belgium  Non disponible                   20  Non disponible
# 5      Netherlands  Non disponible                   25  Non disponible
# 6   United Kingdom  Non disponible                  100  Non disponible
# 7    United States  Non disponible                  500  Non disponible
# 8    United States  Non disponible                  100  Non disponible
# 9    United States  Non disponible                   30  Non disponible
# 10         Finland  Non disponible                   25  Non disponible
# 11          Sweden  Non disponible                   30  Non disponible
# 12        Danemark  Non disponible                   25  Non disponible
# 13          Europe  Non disponible                   50  Non disponible
# 14           Japan  Non disponible                  225  Non disponible
