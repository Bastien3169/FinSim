# %%
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
import numpy as np
import yfinance as yf
import html5lib
import os
import glob

# %%
# Récupération les données historiques pour chaque entreprise (je passe par google colab car fonctionne pas ici ????)

# Charger le fichier et prendre la liste de tous les tikers yahoo des entreprises avec les tikers les infos hist sur yfinance
df = pd.read_csv("/Users/bastoch/ProjectFinance_alleger/data_csv/infos_stocks_concat/infos_stocks_concat.csv", encoding="utf-8")

stocks_tickers_yahoo = df["Ticker_Yahoo_Finance"].to_list()

# Liste pour stocker les DataFrames
dfs = []

for i in liste_stocks_concat:
    try:
        # Récupération des données historiques
        hist = yf.Ticker(i).history(period="max", interval="1wk")

        # Ajouter les colonnes 'Ticker' et 'ShortName'
        hist['Ticker'] = i

        # Ajouter le DataFrame historique dans la liste
        dfs.append(hist)
      
    except Exception as e:
        print(f"Erreur lors de la récupération des données pour {ticker}: {e}")

# Concaténation de tous les DataFrames
df_final = pd.concat(dfs)

# Exportation en CSV
df_final.to_csv("/Users/bastoch/ProjectFinance_alleger/data_csv/historique_stocks_concat/historique_stocks_concat.csv", index=True, encoding='utf-8')

# Affichage des résultats
display(df_final)
# Out:
# Failed to get ticker '7203.T' reason: Expecting value: line 1 column 1 (char 0)
# $7203.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/7203.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=7203.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '6758.T' reason: Expecting value: line 1 column 1 (char 0)
# $6758.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/6758.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=6758.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '8306.T' reason: Expecting value: line 1 column 1 (char 0)
# $8306.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/8306.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=8306.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '6501.T' reason: Expecting value: line 1 column 1 (char 0)
# $6501.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/6501.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=6501.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '8316.T' reason: Expecting value: line 1 column 1 (char 0)
# $8316.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/8316.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=8316.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '6861.T' reason: Expecting value: line 1 column 1 (char 0)
# $6861.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/6861.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=6861.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '9983.T' reason: Expecting value: line 1 column 1 (char 0)
# $9983.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/9983.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=9983.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '6098.T' reason: Expecting value: line 1 column 1 (char 0)
# $6098.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/6098.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=6098.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '7974.T' reason: Expecting value: line 1 column 1 (char 0)
# $7974.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/7974.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=7974.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '9432.T' reason: Expecting value: line 1 column 1 (char 0)
# $9432.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/9432.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=9432.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '4519.T' reason: Expecting value: line 1 column 1 (char 0)
# $4519.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/4519.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=4519.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '9984.T' reason: Expecting value: line 1 column 1 (char 0)
# $9984.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/9984.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=9984.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '8411.T' reason: Expecting value: line 1 column 1 (char 0)
# $8411.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/8411.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=8411.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '8766.T' reason: Expecting value: line 1 column 1 (char 0)
# $8766.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/8766.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=8766.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '8035.T' reason: Expecting value: line 1 column 1 (char 0)
# $8035.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/8035.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=8035.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '9433.T' reason: Expecting value: line 1 column 1 (char 0)
# $9433.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/9433.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=9433.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '9434.T' reason: Expecting value: line 1 column 1 (char 0)
# $9434.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/9434.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=9434.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '8058.T' reason: Expecting value: line 1 column 1 (char 0)
# $8058.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/8058.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=8058.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '8001.T' reason: Expecting value: line 1 column 1 (char 0)
# $8001.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/8001.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=8001.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '4063.T' reason: Expecting value: line 1 column 1 (char 0)
# $4063.T: possibly delisted; no timezone found
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/4063.T?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=4063.T&crumb=Edge%3A+Too+Many+Requests
# Erreur lors de la récupération des données pour BRK-B: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker '8031.T' reason: Expecting value: line 1 column 1 (char 0)
# $8031.T: possibly delisted; no timezone found
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 12
#       9 hist = yf.Ticker(i).history(period="max", interval="1wk")
#      11 # Récupérer le shortName via .info
# ---> 12 short_name = yf.Ticker(i).info.get('shortName', 'Non disponible')
#      14 # Ajouter les colonnes 'Ticker' et 'ShortName'
#      15 hist['Ticker'] = i
#
# File /opt/anaconda3/lib/python3.12/site-packages/yfinance/ticker.py:159, in Ticker.info(self)
#     157 @property
#     158 def info(self) -> dict:
# --> 159     return self.get_info()
#
# File /opt/anaconda3/lib/python3.12/site-packages/yfinance/base.py:229, in TickerBase.get_info(self, proxy)
#     227 def get_info(self, proxy=None) -> dict:
#     228     self._quote.proxy = proxy or self.proxy
# --> 229     data = self._quote.info
#     230     return data
#
# File /opt/anaconda3/lib/python3.12/site-packages/yfinance/scrapers/quote.py:508, in Quote.info(self)
#     505 @property
#     506 def info(self) -> dict:
#     507     if self._info is None:
# --> 508         self._fetch_info(self.proxy)
#     509         self._fetch_complementary(self.proxy)
#     511     return self._info
#
# File /opt/anaconda3/lib/python3.12/site-packages/yfinance/scrapers/quote.py:598, in Quote._fetch_info(self, proxy)
#     596 self._already_fetched = True
#     597 modules = ['financialData', 'quoteType', 'defaultKeyStatistics', 'assetProfile', 'summaryDetail']
# --> 598 result = self._fetch(proxy, modules=modules)
#     599 if result is None:
#     600     self._info = {}
#
# File /opt/anaconda3/lib/python3.12/site-packages/yfinance/scrapers/quote.py:587, in Quote._fetch(self, proxy, modules)
#     585 params_dict = {"modules": modules, "corsDomain": "finance.yahoo.com", "formatted": "false", "symbol": self._symbol}
#     586 try:
# --> 587     result = self._data.get_raw_json(_QUOTE_SUMMARY_URL_ + f"/{self._symbol}", user_agent_headers=self._data.user_agent_headers, params=params_dict, proxy=proxy)
#     588 except requests.exceptions.HTTPError as e:
#     589     utils.get_yf_logger().error(str(e))
#
# File /opt/anaconda3/lib/python3.12/site-packages/yfinance/data.py:398, in YfData.get_raw_json(self, url, user_agent_headers, params, proxy, timeout)
#     396 def get_raw_json(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
#     397     utils.get_yf_logger().debug(f'get_raw_json(): {url}')
# --> 398     response = self.get(url, user_agent_headers=user_agent_headers, params=params, proxy=proxy, timeout=timeout)
#     399     response.raise_for_status()
#     400     return response.json()
#
# File /opt/anaconda3/lib/python3.12/site-packages/yfinance/utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File /opt/anaconda3/lib/python3.12/site-packages/yfinance/data.py:378, in YfData.get(self, url, user_agent_headers, params, proxy, timeout)
#     376     if strategy == 'basic':
#     377         request_args['cookies'] = {cookie.name: cookie.value}
# --> 378     response = self._session.get(**request_args)
#     379     utils.get_yf_logger().debug(f'response code={response.status_code}')
#     381 return response
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/adapters.py:589, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     586     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     588 try:
# --> 589     resp = conn.urlopen(
#     590         method=request.method,
#     591         url=url,
#     592         body=request.body,
#     593         headers=request.headers,
#     594         redirect=False,
#     595         assert_same_host=False,
#     596         preload_content=False,
#     597         decode_content=False,
#     598         retries=self.max_retries,
#     599         timeout=timeout,
#     600         chunked=chunked,
#     601     )
#     603 except (ProtocolError, OSError) as err:
#     604     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
#     464     # Trigger any extra validation we need to do.
#     465     try:
# --> 466         self._validate_conn(conn)
#     467     except (SocketTimeout, BaseSSLError) as e:
#     468         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1093 # Force connect early to allow us to validate the connection.
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1098 if not conn.is_verified and not conn.proxy_is_verified:
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connection.py:652, in HTTPSConnection.connect(self)
#     649 # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     650 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 652 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     653     sock=sock,
#     654     cert_reqs=self.cert_reqs,
#     655     ssl_version=self.ssl_version,
#     656     ssl_minimum_version=self.ssl_minimum_version,
#     657     ssl_maximum_version=self.ssl_maximum_version,
#     658     ca_certs=self.ca_certs,
#     659     ca_cert_dir=self.ca_cert_dir,
#     660     ca_cert_data=self.ca_cert_data,
#     661     cert_file=self.cert_file,
#     662     key_file=self.key_file,
#     663     key_password=self.key_password,
#     664     server_hostname=server_hostname_rm_dot,
#     665     ssl_context=self.ssl_context,
#     666     tls_in_tls=tls_in_tls,
#     667     assert_hostname=self.assert_hostname,
#     668     assert_fingerprint=self.assert_fingerprint,
#     669 )
#     670 self.sock = sock_and_verified.socket
#     672 # Forwarding proxies can never have a verified target since
#     673 # the proxy is the one doing the verification. Should instead
#     674 # use a CONNECT tunnel in order to verify the target.
#     675 # See: https://github.com/urllib3/urllib3/issues/3267.
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connection.py:805, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     802     if is_ipaddress(normalized):
#     803         server_hostname = normalized
# --> 805 ssl_sock = ssl_wrap_socket(
#     806     sock=sock,
#     807     keyfile=key_file,
#     808     certfile=cert_file,
#     809     key_password=key_password,
#     810     ca_certs=ca_certs,
#     811     ca_cert_dir=ca_cert_dir,
#     812     ca_cert_data=ca_cert_data,
#     813     server_hostname=server_hostname,
#     814     ssl_context=context,
#     815     tls_in_tls=tls_in_tls,
#     816 )
#     818 try:
#     819     if assert_fingerprint:
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/util/ssl_.py:465, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     462 except NotImplementedError:  # Defensive: in CI, we always have set_alpn_protocols
#     463     pass
# --> 465 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     466 return ssl_sock
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/util/ssl_.py:509, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     506     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     507     return SSLTransport(sock, ssl_context, server_hostname)
# --> 509 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File /opt/anaconda3/lib/python3.12/ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1042, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039             if timeout == 0.0:
#    1040                 # non-blocking
#    1041                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1042             self.do_handshake()
#    1043 except:
#    1044     try:
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1320, in SSLSocket.do_handshake(self, block)
#    1318     if timeout == 0.0 and block:
#    1319         self.settimeout(None)
# -> 1320     self._sslobj.do_handshake()
#    1321 finally:
#    1322     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
# On clean le fichier !

# Charger le fichier principal
df = pd.read_csv("/Users/bastoch/ProjectFinance_alleger/data_csv/historique_stocks_concat/historique_stocks_concat.csv", encoding="utf-8")

# Supprimer colonnes inutiles
df = df.drop(columns=["Open", "High", "Low", "Volume", "Dividends", "Stock Splits", "Capital Gains", "Adj Close"], errors="ignore")

# Convertir la colonne "Date" en format datetime et reformater en "JJ-MM-AAAA"
df["Date"] = pd.to_datetime(df["Date"], errors="coerce", utc=True).dt.strftime("%d-%m-%Y")

# Renommer la colonne (si nécessaire)
df = df.rename(columns={"Ticker": "Ticker_Yahoo_Finance"})

# Création colonne Ticker sans suffix
df["Ticker"] = df["Ticker_Yahoo_Finance"].str.split(".").str[0]

# Arrondir la colonne "Close"
df["Close"] = df["Close"].round(4)

# Réorganiser les colonnes dans l'ordre souhaité
df = df[["Date", "Close", "Ticker", "Ticker_Yahoo_Finance"]]

# Enregistrer le fichier modifié
df.to_csv("/Users/bastoch/ProjectFinance_alleger/data_csv/historique_stocks_concat/historique_stocks_concat_clean.csv", index=False, encoding="utf-8")

# Afficher un aperçu
display(df.head())
# Out:
#          Date   Close Ticker Ticker_Yahoo_Finance
# 0  08-12-1980  0.0987   AAPL                 AAPL
# 1  15-12-1980  0.0970   AAPL                 AAPL
# 2  22-12-1980  0.1219   AAPL                 AAPL
# 3  29-12-1980  0.1185   AAPL                 AAPL
# 4  05-01-1981  0.1095   AAPL                 AAPL
